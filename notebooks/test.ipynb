# %%
import matplotlib.pyplot as plt

# %%
# plot example
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Simple Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 # plot example
# ----> 2 plt.plot([1, 2, 3], [4, 5, 6])
#       3 plt.title("Simple Plot")
#       4 plt.xlabel("X-axis")
#
# File ~/scratch/AdversarialSimulation/.venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2730, in plot(scalex, scaley, data, *args, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.plot)
#    2729 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2730     return gca().plot(
#    2731         *args, scalex=scalex, scaley=scaley,
#    2732         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/scratch/AdversarialSimulation/.venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2227, in gca()
#    2225 @_copy_docstring_and_deprecators(Figure.gca)
#    2226 def gca():
# -> 2227     return gcf().gca()
#
# ...
